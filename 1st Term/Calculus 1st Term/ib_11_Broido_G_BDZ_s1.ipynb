# %%
import sympy as sp
import numpy as np
from sympy import Symbol
from matplotlib import style
import matplotlib.pyplot as plt

style.use('ggplot') # отображение сетки координат по умолчанию
x = Symbol('x')

# %%
'''
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid(True)
plt.axis('equal')
plt.xlabel('x')
plt.ylabel('y')
'''
plt.subplot(2,4,1)
x = np.linspace(-2,2,100)
y1, = plt.plot(x, x**2, 'b-', label='$y = x^2$')
y2, = plt.plot(x, x**(1/2), 'r:', label='$y = x^0.5$')
plt.legend(handles = [y1, y2])
plt.title('1')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid(True)
#plt.axis('equal')
plt.xlabel('x')
plt.ylabel('y')
''''''
plt.subplot(2,4,2)
x = np.linspace(-2,2,100)
y1, = plt.plot(x, x**(1/3), 'b-', label='$y = x^(1/3)$')
y2, = plt.plot(x, x**3, 'r:', label='$y = x**3$')
plt.legend(handles = [y1, y2])
plt.title('2')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid(True)
#plt.axis('equal')
plt.xlabel('x')
plt.ylabel('y')

plt.subplot(2,4,3)
from math import e
x = np.linspace(-2,2,100)
y1, = plt.plot(x, np.exp(x), 'b-', label='$y = e^x$')
y2, = plt.plot(x, sp.log(x), 'r:', label='$y = ln(x)$')
plt.legend(handles = [y1, y2])
plt.title('3')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid(True)
#plt.axis('equal')
plt.xlabel('x')
plt.ylabel('y')

plt.subplot(2,4,4)
x = np.linspace(0.00001, 16, 250)
log_of_x = np.emath.logn(1/2, x)
y1, = plt.plot(x, log_of_x, label='$log(1/2)(x)$')
x = np.linspace(-4,15,400)
y2, = plt.plot(x, (1/2)**x, label='$(1/2)^x$')
plt.legend(handles = [y1,y2])
plt.title('4')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid(True)
#plt.axis('equal')
plt.xlabel('x')
plt.ylabel('y')

plt.subplot(2,4,5)
x = np.linspace( -(np.pi)/2, (np.pi)/2, 100)
y1, = plt.plot(x, np.sin(x), 'b-', label = '$y=sin(x)$')
y2, = plt.plot(x, np.arcsin(x), 'r:', label = '$y=arcsin(x)$')
y_sym=plt.plot(x, x, 'm-', '$y=x$')

plt.legend(handles = [y1, y2])
plt.title('5')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid(True)
#plt.axis('equal')
plt.xlabel('x')
plt.ylabel('y')
#plt.title('Графики sin, arcsin и ось их симметрии')

plt.subplot(2,4,6)
x = np.linspace( -(np.pi)/2.5, (np.pi)/2.5, 100)
y1, = plt.plot(x, np.tan(x), 'b-', label = '$y=tg(x)$')
y2, = plt.plot(x, np.arctan(x), 'r:', label = '$y=arctg(x)$')
plt.legend(handles = [y1, y2])
plt.title('6')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid(True)
#plt.axis('equal')
plt.xlabel('x')
plt.ylabel('y')

plt.subplot(2,4,7)
x = np.linspace(-np.pi, np.pi, 1000)
y1, = plt.plot(x, np.cos(x), 'r:', label='y=cos(x)')
y2, = plt.plot(x, np.arccos(x), 'b-', label='y=arccos(x)')
plt.legend(handles = [y1, y2])
plt.title('7')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid(True)
#plt.axis('equal')
plt.xlabel('x')
plt.ylabel('y')

plt.subplot(2,4,8)
x = np.linspace( 0, (np.pi), 100)
y1, = plt.plot(x, 1 / np.tan(x), 'b-', label = '$y=ctg(x)$')
y2, = plt.plot(x, np.pi/2 - np.arctan(x), 'r:', label = '$y=arcctg(x)$')
plt.legend(handles = [y1, y2])
plt.title('8')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid(True)
#plt.axis('equal')
plt.xlabel('x')
plt.ylabel('y')

plt.show()
# Out:
# C:\Users\Thunboo\AppData\Local\Temp\ipykernel_8728\3253633056.py:12: RuntimeWarning: invalid value encountered in sqrt
#   y2, = plt.plot(x, x**(1/2), 'r:', label='$y = x^0.5$')
# C:\Users\Thunboo\AppData\Local\Temp\ipykernel_8728\3253633056.py:24: RuntimeWarning: invalid value encountered in power
#   y1, = plt.plot(x, x**(1/3), 'b-', label='$y = x^(1/3)$')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      71 try:
# ---> 72     retval = cfunc(*args, **kwargs)
#      73 except TypeError as e:
#
# TypeError: unhashable type: 'numpy.ndarray'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      71 try:
# ---> 72     retval = cfunc(*args, **kwargs)
#      73 except TypeError as e:
#
# TypeError: unhashable type: 'numpy.ndarray'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# c:\Users\Thunboo\Documents\VS Code\Матанализ\ib_11_Broido_G_BDZ_s1.ipynb Cell 2 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/Thunboo/Documents/VS%20Code/%D0%9C%D0%B0%D1%82%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7/ib_11_Broido_G_BDZ_s1.ipynb#W1sZmlsZQ%3D%3D?line=36'>37</a> x = np.linspace(-2,2,100)
#      <a href='vscode-notebook-cell:/c%3A/Users/Thunboo/Documents/VS%20Code/%D0%9C%D0%B0%D1%82%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7/ib_11_Broido_G_BDZ_s1.ipynb#W1sZmlsZQ%3D%3D?line=37'>38</a> y1, = plt.plot(x, np.exp(x), 'b-', label='$y = e^x$')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Thunboo/Documents/VS%20Code/%D0%9C%D0%B0%D1%82%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7/ib_11_Broido_G_BDZ_s1.ipynb#W1sZmlsZQ%3D%3D?line=38'>39</a> y2, = plt.plot(x, sp.log(x), 'r:', label='$y = ln(x)$')
#      <a href='vscode-notebook-cell:/c%3A/Users/Thunboo/Documents/VS%20Code/%D0%9C%D0%B0%D1%82%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7/ib_11_Broido_G_BDZ_s1.ipynb#W1sZmlsZQ%3D%3D?line=39'>40</a> plt.legend(handles = [y1, y2])
#      <a href='vscode-notebook-cell:/c%3A/Users/Thunboo/Documents/VS%20Code/%D0%9C%D0%B0%D1%82%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7/ib_11_Broido_G_BDZ_s1.ipynb#W1sZmlsZQ%3D%3D?line=40'>41</a> plt.title('3')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\core\cache.py:76, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      74     if not e.args or not e.args[0].startswith('unhashable type:'):
#      75         raise
# ---> 76     retval = func(*args, **kwargs)
#      77 return retval
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\core\function.py:466, in Function.__new__(cls, *args, **options)
#     458     raise TypeError(temp % {
#     459         'name': cls,
#     460         'qual': 'exactly' if len(cls.nargs) == 1 else 'at least',
#     461         'args': min(cls.nargs),
#     462         'plural': 's'*(min(cls.nargs) != 1),
#     463         'given': n})
#     465 evaluate = options.get('evaluate', global_parameters.evaluate)
# --> 466 result = super().__new__(cls, *args, **options)
#     467 if evaluate and isinstance(result, cls) and result.args:
#     468     _should_evalf = [cls._should_evalf(a) for a in result.args]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\core\cache.py:76, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      74     if not e.args or not e.args[0].startswith('unhashable type:'):
#      75         raise
# ---> 76     retval = func(*args, **kwargs)
#      77 return retval
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\core\function.py:307, in Application.__new__(cls, *args, **options)
#     304     raise ValueError("Unknown options: %s" % options)
#     306 if evaluate:
# --> 307     evaluated = cls.eval(*args)
#     308     if evaluated is not None:
#     309         return evaluated
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\functions\elementary\exponential.py:735, in log.eval(cls, arg, base)
#     733 # don't autoexpand Pow or Mul (see the issue 3351):
#     734 if not arg.is_Add:
# --> 735     coeff = arg.as_coefficient(I)
#     737     if coeff is not None:
#     738         if coeff is S.Infinity:
#
# AttributeError: 'ImmutableDenseNDimArray' object has no attribute 'as_coefficient'

# %%
# 1)
y = x**2
y_inv = x**0.5
sp.plot( (y, (x,-2,2)), (y_inv, (x,-2,2)))
# Out:
# <string>:1: RuntimeWarning: invalid value encountered in scalar power

# %%
# 2)
y = x**(1/3)
y_inv = x**3
sp.plot( (y, (x,-1,2)), (y_inv, (x,-2,2)))
# Out:
# <string>:1: RuntimeWarning: invalid value encountered in scalar power

# %%
# 3)
from math import e
y = e**(x)
y_inv = sp.log(x)
sp.plot( (y, (x,-1,2)), (y_inv, (x,-1,2)))

# %%
# 4)
x = np.linspace(0.00001, 16, 250)
log_of_x = np.emath.logn(1/2, x)

y1, = plt.plot(x, log_of_x, label='$log(1/2)(x)$')

x = np.linspace(-4,15,400)
y2, = plt.plot(x, (1/2)**x, label='$(1/2)^x$')

plt.legend(handles = [y1,y2])
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid(True)
plt.axis('equal')
plt.title('?')
plt.xlabel('x')
plt.ylabel('y')

plt.show()

# %%
# 5)
x = np.linspace( -(np.pi)/2, (np.pi)/2, 100)
y1, = plt.plot(x, np.sin(x), 'b-', label = '$y=sin(x)$')
y2, = plt.plot(x, np.arcsin(x), 'r:', label = '$y=arcsin(x)$')
y_sym=plt.plot(x, x, 'm-', '$y=x$')

plt.legend(handles = [y1, y2])
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.axis('equal')
plt.grid(True)

plt.xlabel('x')
plt.ylabel('y')
plt.title(' График sin и arcsin, ось их симметрии ')

plt.show()
# Out:
# C:\Users\Thunboo\AppData\Local\Temp\ipykernel_5688\1589207944.py:4: RuntimeWarning: invalid value encountered in arcsin
#   y2, = plt.plot(x, np.arcsin(x), 'r:', label = '$y=arcsin(x)$')

# %%
# 6)
x = np.linspace( -(np.pi)/2.5, (np.pi)/2.5, 100)
y1, = plt.plot(x, np.tan(x), 'b-', label = '$y=tg(x)$')
y2, = plt.plot(x, np.arctan(x), 'r:', label = '$y=arctg(x)$')

plt.legend(handles = [y1, y2])
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.axis('equal')
plt.grid(True)

plt.xlabel('x')
plt.ylabel('y')
plt.title('График tg и arctg')

plt.show()
#'''

# %%
# 7)
x = np.linspace(-np.pi, np.pi, 1000)

y1, = plt.plot(x, np.cos(x), 'r:', label='y=cos(x)')
y2, = plt.plot(x, np.arccos(x), 'b-', label='y=arccos(x)')

plt.legend(handles = [y1, y2])
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.axis('equal')
plt.grid(True)

plt.xlabel('x')
plt.ylabel('y')
plt.title('График cos и arccos')
plt.show()
# Out:
# C:\Users\Thunboo\AppData\Local\Temp\ipykernel_8812\117758307.py:5: RuntimeWarning: invalid value encountered in arccos
#   y2, = plt.plot(x, np.arccos(x), 'b-', label='y=arccos(x)')

# %%
# 8)
x = np.linspace( 0, (np.pi), 100)
y1, = plt.plot(x, 1 / np.tan(x), 'b-', label = '$y=ctg(x)$')
y2, = plt.plot(x, np.pi/2 - np.arctan(x), 'r:', label = '$y=arcctg(x)$')

plt.legend(handles = [y1, y2])
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.axis('equal')
plt.grid(True)

plt.xlim(0, 2)
plt.ylim(-5,5)
plt.xlabel('x')
plt.ylabel('y')
plt.title('График ctg и arcctg')

plt.show()
'''
print(np.tan(np.pi/3), np.pi/3)
print(np.arctan(np.sqrt(3)), np.sqrt(3))
print()
print(1 / np.tan(np.pi/3), 1 / (np.pi/3))
print(1 / np.arctan(np.sqrt(3)), 1 / np.sqrt(3))
print(1 / np.arctan(np.tan(2)), 2)
'''
# Out:
# C:\Users\Thunboo\AppData\Local\Temp\ipykernel_8812\3914853468.py:3: RuntimeWarning: divide by zero encountered in divide
#   y1, = plt.plot(x, 1 / np.tan(x), 'b-', label = '$y=ctg(x)$')
# '\nprint(np.tan(np.pi/3), np.pi/3)\nprint(np.arctan(np.sqrt(3)), np.sqrt(3))\nprint()\nprint(1 / np.tan(np.pi/3), 1 / (np.pi/3))\nprint(1 / np.arctan(np.sqrt(3)), 1 / np.sqrt(3))\nprint(1 / np.arctan(np.tan(2)), 2)\n'
